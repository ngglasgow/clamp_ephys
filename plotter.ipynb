# %%
import clamp_ephys
import pandas as pd
import os
import scipy
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact
from bokeh.io import output_notebook, show, push_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1263">Loading BokehJS ...</span>
#     </div>

# %%
lowpass_freq = 500  # Hz
stim_time = 500     # ms
post_stim = 250     # ms, amount of time after stimulus to look for max value
tp_start = 5        # ms, time of start of test pulse
vm_jump = 10        # mV, test pulse voltage jump
pre_tp = 3          # ms, amount of time before test pulse start to get baseline
unit_scaler = -12   # unitless, scaler to get back to A, from pA
amp_factor = 1      # scaler for making plots in pA
fs = 25             # kHz, the sampling frequency

'''#################### THIS LOOP RUNS THE SINGLE CELL ANALYSIS #################### '''
data_path = os.path.join(os.getcwd(), 'test_data', 'p2_data_notes.csv')

cell_path = os.path.join(os.getcwd(), 'test_data', 'JH200303_c1_light100.ibw')
data = clamp_ephys.workflows.cell(cell_path, fs=fs, path_to_data_notes=data_path, timepoint='p2', amp_factor=amp_factor)

data.get_raw_peaks(stim_time, post_stim)
data.filter_traces(lowpass_freq)

# %%
trace = data.traces_filtered[0].values
time = np.arange(0, len(trace) / data.fs, 1 / data.fs)
peaks, properties = scipy.signal.find_peaks(trace * -1, prominence=10)
time_peaks = peaks / data.fs

p = figure(plot_width=800, plot_height=400)

sweep = p.line(time, trace, line_width=2)
# p.circle(time_peaks, trace[peaks], size=5, line_color="navy", fill_color="orange", fill_alpha=0.5)

show(p, notebook_handle=True)
# Out:
#   <div class="bk-root" id="733d0cf0-f71c-47e8-863d-2e10ead6bf89" data-root-id="1385"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[19]</strong>&gt;</code></p>

# %%
from bokeh.models import Slider
from bokeh.layouts import column

# %%
def update(sweep_number):
    sweep.data_source.data['y'] = data.traces_filtered[sweep_number]
    push_notebook()

# %%
interact(update, sweep_number=(0, len(data.traces_filtered.columns) - 1, 1))
# Out:
# interactive(children=(IntSlider(value=14, description='sweep_number', max=29), Output()), _dom_classes=('widge…
# <function __main__.update(sweep_number)>

# %%
slider.js_link('value',  )
